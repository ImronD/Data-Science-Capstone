# %% [markdown]
# <h1><center>Opening an upscale hotel in Los Angeles</center></h1>
#
# ## Final Report
#
# ### Tasks :
# * Scrape metadata of each neighborhood in Los Angeles from la times to build a dataframe.
# * Obtain coordinates of each neighborhood in order to later on plot each one on the map.
# * Aquire nearby venues using the FourSquare API.
# * Clean Data.
# * Segment each neighborhood into a cluster.
# * Form an opinion on the neighborhoods in ragards to opening an upscale hotel there.

# %% [markdown]
# # Import necessary libraries

# %%
# If these packages are not yet installed on your machine.
#! pip install folium
#! pip install geocoder

# Libraries for creating dataframes.
import pandas as pd
pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", None)

# Libraries for web-scraping
from bs4 import BeautifulSoup
import requests
import json
from pandas.io.json import json_normalize

# Method for clustering.
from sklearn.cluster import KMeans

# Libraries for plotting maps.
import geocoder
from geopy.geocoders import Nominatim
import folium
print("Finished!")
# Out:
# Finished!

# %% [markdown]
# # Scraping LA Times for Data

# %%
url = "https://maps.latimes.com/neighborhoods/income/median/neighborhood/list/"
data = requests.get(url).text
soup = BeautifulSoup(data,"html.parser")
table = soup.find(id = "sortable_table")

# %%
# Scrape for each neighborhood name in container.

# List of neighborhood names.
neighborhoodList = [table.find_all('a')[i]['name'] for i in range(len(table.find_all('a')))]
neighborhoodList = [hName.replace("-"," ") for hName in neighborhoodList]

# List of median household incomes by neighborhood in LA.
incomeTd = table.find_all(style="font-size:17px; padding-left:5px; line-height:160%; text-align:right;")
incomeList = []

# Cleanse data from HTML lines to list strings.
for line in incomeTd:
    
    # Find where the string contains '$' in order to know that's the income numbers.
    startIndex = str(line).find("$")
    endIndex = str(line).find("</td>")
    income = str(line)[startIndex + 1:endIndex]
    incomeList.append(income)

# Remove commas from each number in list.
incomeList = [num.replace(',','') for num in incomeList]

# Convert each string object to float for ease of use during analysis.
incomeList = [float(num) for num in incomeList]

# Confirm that lists are equal in length.
print(len(incomeList) == len(neighborhoodList))
# Out:
# True

# %% [markdown]
# # Creating a dataframe for our data

# %%
#laData = pd.DataFrame()
#laData["Neighborhood"] = neighborhoodList
#laData["Median-Income"] = incomeList

laData.head
# Out:
# <bound method NDFrame.head of                   Neighborhood  Median-Income
# 0                      bel air       207938.0
# 1                 hidden hills       203199.0
# 2                rolling hills       184777.0
# 3                beverly crest       169282.0
# 4            pacific palisades       168008.0
# 5         palos verdes estates       167344.0
# 6                   san marino       158855.0
# 7         la canada flintridge       148996.0
# 8        rolling hills estates       145628.0
# 9                       malibu       138215.0
# 10            la habra heights       137034.0
# 11             manhattan beach       136481.0
# 12      santa monica mountains       132997.0
# 13         rancho palos verdes       128321.0
# 14            westlake village       126550.0
# 15                   calabasas       126178.0
# 16              west san dimas       125984.0
# 17                    bradbury       123773.0
# 18             stevenson ranch       122833.0
# 19                porter ranch       121428.0
# 20                     topanga       120319.0
# 21              ladera heights       117925.0
# 22                agoura hills       117608.0
# 23                leona valley       117526.0
# 24                   brentwood       112927.0
# 25               cheviot hills       111813.0
# 26               hermosa beach       109509.0
# 27                     castaic       108693.0
# 28        hollywood hills west       108199.0
# 29                      walnut       106893.0
# 30               hasley canyon       106489.0
# 31                  agua dulce       106078.0
# 32                 beverlywood       105253.0
# 33          northwest palmdale       103013.0
# 34                  west hills       103008.0
# 35                    cerritos        98212.0
# 36               beverly hills        96312.0
# 37                century city        95135.0
# 38              north whittier        93841.0
# 39      santa susana mountains        93825.0
# 40             castaic canyons        93248.0
# 41                 san pasqual        92917.0
# 42                 ridge route        92822.0
# 43              marina del rey        92763.0
# 44                 diamond bar        92414.0
# 45               redondo beach        92263.0
# 46               playa del rey        91339.0
# 47              woodland hills        89946.0
# 48                   claremont        89804.0
# 49               santa clarita        88987.0
# 50                sierra madre        88008.0
# 51            west los angeles        86403.0
# 52                      ramona        86325.0
# 53             tujunga canyons        85625.0
# 54                hancock park        85277.0
# 55                   san dimas        84953.0
# 56                  chatsworth        84456.0
# 57                       acton        83983.0
# 58                  el segundo        83925.0
# 59               granada hills        83911.0
# 60                   la mirada        83514.0
# 61                    la verne        83352.0
# 62                shadow hills        82796.0
# 63       la crescenta montrose        82693.0
# 64                    altadena        82676.0
# 65                    glendora        81336.0
# 66                      vernon        81279.0
# 67     view park windsor hills        81214.0
# 68       desert view highlands        80867.0
# 69            hacienda heights        80762.0
# 70                    lakewood        78764.0
# 71                green valley        78712.0
# 72                      encino        78529.0
# 73                 quartz hill        77498.0
# 74                 westchester        77473.0
# 75                    torrance        76866.0
# 76              south pasadena        76229.0
# 77              elizabeth lake        75951.0
# 78                     arcadia        75808.0
# 79               mission hills        75675.0
# 80                 studio city        75657.0
# 81                 lake hughes        74918.0
# 82               east pasadena        73690.0
# 83                     tarzana        73195.0
# 84                 toluca lake        73111.0
# 85               angeles crest        72841.0
# 86             rowland heights        72638.0
# 87            rancho dominguez        72097.0
# 88                 west covina        71898.0
# 89                     carthay        71398.0
# 90                 culver city        70774.0
# 91                      carson        70645.0
# 92   southeast antelope valley        70134.0
# 93                     valinda        70037.0
# 94              east la mirada        69930.0
# 95                 rancho park        69724.0
# 96                sherman oaks        69651.0
# 97             hollywood hills        69277.0
# 98                santa monica        69013.0
# 99                     sunland        68720.0
# 100                   westwood        68716.0
# 101                playa vista        68597.0
# 102                     duarte        68539.0
# 103                charter oak        68092.0
# 104                  val verde        68073.0
# 105          lake view terrace        67985.0
# 106                 northridge        67906.0
# 107                     venice        67647.0
# 108          mayflower village        67592.0
# 109                 eagle rock        67253.0
# 110                   whittier        66891.0
# 111                west carson        66805.0
# 112                     citrus        66638.0
# 113                   industry        66616.0
# 114                   del aire        66442.0
# 115                     covina        66438.0
# 116                signal hill        66283.0
# 117                    vincent        66221.0
# 118                temple city        65965.0
# 119                    fairfax        65938.0
# 120                     sylmar        65783.0
# 121                     arleta        65649.0
# 122       south san jose hills        65527.0
# 123                lake balboa        65336.0
# 124          south san gabriel        64827.0
# 125         west puente valley        64809.0
# 126             south whittier        64670.0
# 127            avocado heights        64544.0
# 128                    burbank        64416.0
# 129           east san gabriel        64365.0
# 130             pico robertson        63356.0
# 131                   palmdale        63317.0
# 132              beverly grove        63039.0
# 133                   pasadena        62825.0
# 134                  mar vista        62611.0
# 135                   winnetka        62535.0
# 136                    norwalk        62412.0
# 137                    del rey        62259.0
# 138                     downey        61839.0
# 139             windsor square        61767.0
# 140   west whittier los nietos        61504.0
# 141                   monrovia        61504.0
# 142         lopezkagel canyons        61398.0
# 143                  irwindale        60959.0
# 144                 littlerock        60781.0
# 145    veterans administration        60561.0
# 146                    artesia        60538.0
# 147           santa fe springs        60445.0
# 148                     lomita        59059.0
# 149  northwest antelope valley        58899.0
# 150               mid wilshire        58483.0
# 151                    tujunga        58001.0
# 152              gramercy park        57983.0
# 153           mount washington        57725.0
# 154                   sawtelle        57710.0
# 155                  san pedro        57508.0
# 156               alondra park        57177.0
# 157                   glendale        57112.0
# 158                san gabriel        56687.0
# 159                pico rivera        56683.0
# 160               baldwin park        56585.0
# 161             north el monte        56577.0
# 162            catalina island        56295.0
# 163                sun village        56175.0
# 164                  lancaster        56069.0
# 165                  la puente        55902.0
# 166          montecito heights        55901.0
# 167             valley village        55470.0
# 168                harbor city        55454.0
# 169              monterey park        55210.0
# 170                     reseda        54771.0
# 171                silver lake        54339.0
# 172                     pomona        54242.0
# 173               san fernando        54068.0
# 174            atwater village        53872.0
# 175                 bellflower        53325.0
# 176                      azusa        53299.0
# 177                   alhambra        53224.0
# 178                     avalon        53200.0
# 179                   lawndale        53150.0
# 180                    gardena        52897.0
# 181             west hollywood        52855.0
# 182                 montebello        52623.0
# 183                north hills        52456.0
# 184  northeast antelope valley        52234.0
# 185           lake los angeles        52146.0
# 186                canoga park        51601.0
# 187                 sun valley        51290.0
# 188                 long beach        50985.0
# 189                  los feliz        50793.0
# 190                      palms        50684.0
# 191              glassell park        50098.0
# 192                  paramount        49815.0
# 193                   rosemead        49387.0
# 194                    pacoima        49066.0
# 195             elysian valley        49013.0
# 196                     athens        48824.0
# 197                walnut park        48750.0
# 198                    lynwood        48518.0
# 199                 south gate        48312.0
# 200               west compton        48093.0
# 201             harbor gateway        47849.0
# 202                  larchmont        47780.0
# 203             south el monte        46912.0
# 204           hawaiian gardens        46853.0
# 205                  inglewood        46574.0
# 206                   commerce        46245.0
# 207                valley glen        46175.0
# 208          manchester square        46093.0
# 209                  el sereno        45866.0
# 210               leimert park        45865.0
# 211              highland park        45478.0
# 212              panorama city        44468.0
# 213               east compton        44439.0
# 214                   el monte        44415.0
# 215                   mid city        43711.0
# 216                  hawthorne        43602.0
# 217                    compton        43157.0
# 218            north hollywood        42791.0
# 219               cypress park        42615.0
# 220               bell gardens        41532.0
# 221                    maywood        41203.0
# 222                   van nuys        41134.0
# 223                 wilmington        40627.0
# 224                       bell        40556.0
# 225                  hyde park        39460.0
# 226            huntington park        39185.0
# 227                     cudahy        39048.0
# 228           east los angeles        38621.0
# 229                willowbrook        38224.0
# 230                 west adams        38209.0
# 231      baldwin hillscrenshaw        37948.0
# 232                     lennox        37937.0
# 233        chesterfield square        37737.0
# 234                  echo park        37708.0
# 235               harvard park        37013.0
# 236         florence firestone        34408.0
# 237            exposition park        33999.0
# 238                  hollywood        33694.0
# 239              boyle heights        33235.0
# 240             jefferson park        32654.0
# 241                   westmont        31572.0
# 242            central alameda        31559.0
# 243          arlington heights        31421.0
# 244              green meadows        31347.0
# 245              vermont vista        31272.0
# 246            vermont slauson        31236.0
# 247            harvard heights        31173.0
# 248     historic south central        30882.0
# 249            lincoln heights        30579.0
# 250                  koreatown        30558.0
# 251             east hollywood        29927.0
# 252             vermont square        29904.0
# 253        broadway manchester        29897.0
# 254            adams normandie        29606.0
# 255                 south park        29518.0
# 256                   florence        29447.0
# 257               elysian park        28263.0
# 258             vermont knolls        27730.0
# 259                   westlake        26757.0
# 260                 pico union        26424.0
# 261                      watts        25161.0
# 262                  chinatown        22754.0
# 263            university park        18533.0
# 264                   downtown        15003.0>

# %% [markdown]
# # Getting coordinates for each neighborhood.

# %%
# Lists containing column values for each neighborhood.
lats = []
longs = []
hoodNames = []

# Create coordinates dataframe.
coordinatesDf = pd.DataFrame(columns = ["Neighborhood","Latidude","Longitude"])

# Iterate over each neighborhood in the dataframe and retrieve it's coordinates.
geolocator = Nominatim(user_agent="http")

# %%
# Get coordinates for each neighborhood.
for ind, hood in enumerate(laData["Neighborhood"]):
    print(hood,ind)
    try:
        address = geolocator.geocode("{} , Los Angeles".format(hood))
    except:
        continue
    if address == None:
        continue
    else:
        lats.append(address.latitude)
        longs.append(address.longitude)
        hoodNames.append(hood)
# Out:
# bel air 0
# hidden hills 1
# rolling hills 2
# beverly crest 3
# pacific palisades 4
# palos verdes estates 5
# san marino 6
# la canada flintridge 7
# rolling hills estates 8
# malibu 9
# la habra heights 10
# manhattan beach 11
# santa monica mountains 12
# rancho palos verdes 13
# westlake village 14
# calabasas 15
# west san dimas 16
# bradbury 17
# stevenson ranch 18
# porter ranch 19
# topanga 20
# ladera heights 21
# agoura hills 22
# leona valley 23
# brentwood 24
# cheviot hills 25
# hermosa beach 26
# castaic 27
# hollywood hills west 28
# walnut 29
# hasley canyon 30
# agua dulce 31
# beverlywood 32
# northwest palmdale 33
# west hills 34
# cerritos 35
# beverly hills 36
# century city 37
# north whittier 38
# santa susana mountains 39
# castaic canyons 40
# san pasqual 41
# ridge route 42
# marina del rey 43
# diamond bar 44
# redondo beach 45
# playa del rey 46
# woodland hills 47
# claremont 48
# santa clarita 49
# sierra madre 50
# west los angeles 51
# ramona 52
# tujunga canyons 53
# hancock park 54
# san dimas 55
# chatsworth 56
# acton 57
# el segundo 58
# granada hills 59
# la mirada 60
# la verne 61
# shadow hills 62
# la crescenta montrose 63
# altadena 64
# glendora 65
# vernon 66
# view park windsor hills 67
# desert view highlands 68
# hacienda heights 69
# lakewood 70
# green valley 71
# encino 72
# quartz hill 73
# westchester 74
# torrance 75
# south pasadena 76
# elizabeth lake 77
# arcadia 78
# mission hills 79
# studio city 80
# lake hughes 81
# east pasadena 82
# tarzana 83
# toluca lake 84
# angeles crest 85
# rowland heights 86
# rancho dominguez 87
# west covina 88
# carthay 89
# culver city 90
# carson 91
# southeast antelope valley 92
# valinda 93
# east la mirada 94
# rancho park 95
# sherman oaks 96
# hollywood hills 97
# santa monica 98
# sunland 99
# westwood 100
# playa vista 101
# duarte 102
# charter oak 103
# val verde 104
# lake view terrace 105
# northridge 106
# venice 107
# mayflower village 108
# eagle rock 109
# whittier 110
# west carson 111
# citrus 112
# industry 113
# del aire 114
# covina 115
# signal hill 116
# vincent 117
# temple city 118
# fairfax 119
# sylmar 120
# arleta 121
# south san jose hills 122
# lake balboa 123
# south san gabriel 124
# west puente valley 125
# south whittier 126
# avocado heights 127
# burbank 128
# east san gabriel 129
# pico robertson 130
# palmdale 131
# beverly grove 132
# pasadena 133
# mar vista 134
# winnetka 135
# norwalk 136
# del rey 137
# downey 138
# windsor square 139
# west whittier los nietos 140
# monrovia 141
# lopezkagel canyons 142
# irwindale 143
# littlerock 144
# veterans administration 145
# artesia 146
# santa fe springs 147
# lomita 148
# northwest antelope valley 149
# mid wilshire 150
# tujunga 151
# gramercy park 152
# mount washington 153
# sawtelle 154
# san pedro 155
# alondra park 156
# glendale 157
# san gabriel 158
# pico rivera 159
# baldwin park 160
# north el monte 161
# catalina island 162
# sun village 163
# lancaster 164
# la puente 165
# montecito heights 166
# valley village 167
# harbor city 168
# monterey park 169
# reseda 170
# silver lake 171
# pomona 172
# san fernando 173
# atwater village 174
# bellflower 175
# azusa 176
# alhambra 177
# avalon 178
# lawndale 179
# gardena 180
# west hollywood 181
# montebello 182
# north hills 183
# northeast antelope valley 184
# lake los angeles 185
# canoga park 186
# sun valley 187
# long beach 188
# los feliz 189
# palms 190
# glassell park 191
# paramount 192
# rosemead 193
# pacoima 194
# elysian valley 195
# athens 196
# walnut park 197
# lynwood 198
# south gate 199
# west compton 200
# harbor gateway 201
# larchmont 202
# south el monte 203
# hawaiian gardens 204
# inglewood 205
# commerce 206
# valley glen 207
# manchester square 208
# el sereno 209
# leimert park 210
# highland park 211
# panorama city 212
# east compton 213
# el monte 214
# mid city 215
# hawthorne 216
# compton 217
# north hollywood 218
# cypress park 219
# bell gardens 220
# maywood 221
# van nuys 222
# wilmington 223
# bell 224
# hyde park 225
# huntington park 226
# cudahy 227
# east los angeles 228
# willowbrook 229
# west adams 230
# baldwin hillscrenshaw 231
# lennox 232
# chesterfield square 233
# echo park 234
# harvard park 235
# florence firestone 236
# exposition park 237
# hollywood 238
# boyle heights 239
# jefferson park 240
# westmont 241
# central alameda 242
# arlington heights 243
# green meadows 244
# vermont vista 245
# vermont slauson 246
# harvard heights 247
# historic south central 248
# lincoln heights 249
# koreatown 250
# east hollywood 251
# vermont square 252
# broadway manchester 253
# adams normandie 254
# south park 255
# florence 256
# elysian park 257
# vermont knolls 258
# westlake 259
# pico union 260
# watts 261
# chinatown 262
# university park 263
# downtown 264

# %% [markdown]
# # Creating a dataframe with coordinates

# %%
# Creating the dataframe.
coordinateDf = pd.DataFrame()

# Filling the dataframe with data.
coordinateDf["Neighborhood"] = hoodNames
coordinateDf["Latitude"] = lats
coordinateDf["Longitude"] = longs

coordinateDf.head()
# Out:
#         Neighborhood   Latitude   Longitude
# 0            bel air  34.098883 -118.459881
# 1       hidden hills  34.164091 -118.657837
# 2      rolling hills  33.766804 -118.349662
# 3      beverly crest  34.116770 -118.432261
# 4  pacific palisades  34.048064 -118.526471

# %% [markdown]
# # Merging the two dataframes

# %%
totalLaDf = coordinateDf.merge(laData, on = "Neighborhood")

# Making sure the size of the dataframe is correct.
totalLaDf.shape

# Saving the dataframe.
totalLaDf.to_csv("totalDf.csv",index = False)

totalLaDf.head()
# Out:
#         Neighborhood   Latitude   Longitude  Median-Income
# 0            bel air  34.098883 -118.459881       207938.0
# 1       hidden hills  34.164091 -118.657837       203199.0
# 2      rolling hills  33.766804 -118.349662       184777.0
# 3      beverly crest  34.116770 -118.432261       169282.0
# 4  pacific palisades  34.048064 -118.526471       168008.0

# %% [markdown]
# # Creating a map of all the neighborhoods.

# %%
address = "Los Angeles, California"

# Getting coordinates of LA.
geolocator = Nominatim(user_agent="html")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print("The geograpical coordinate of Los Angeles, California {}, {}.".format(latitude, longitude))
# Out:
# The geograpical coordinate of Los Angeles, California 34.0536909, -118.2427666.

# %%
laMap = folium.Map(location = [latitude,longitude], 
                  zoom_start = 11, tiles = "stamentoner")
for name,lat,long,income in zip(totalLaDf["Neighborhood"],totalLaDf["Latitude"],totalLaDf["Longitude"],totalLaDf["Median-Income"]):
    folium.CircleMarker(
    radius=15,
    location=[lat,long],
    popup='Name : {}\n Income : ${}'.format(name,income),
    color="magenta",
    fill_color = "magenta",
    fill=True,
    fill_opacity = .5,
).add_to(laMap)
    
laMap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Save map.
laMap.save("laMap.html")

# %% [markdown]
# # Using FourSquare to retrieve nearby hotels for each neighborhood

# %%
# @hidden_cell
CLIENT_ID = "ODSQDIMDMLN4QZUGZMUJJPEF2H31HCHPM2ZHBNJFHZH0C4F4"
CLIENT_SECRET = "C0MSMI1XRWEFWG5J3O2UE2KDKC5SLH4XDS3XYXKHR5BTDRHT"
VERSION = "20180605"
LIMIT = 200

# %%
venues = []
# Get nearby venues for each neighborhood.
for lat,long,hood in zip(totalLaDf["Latitude"],totalLaDf["Longitude"],totalLaDf["Neighborhood"]):
    
    # URL to get data from FourSquare.
    url = "https://api.foursquare.com/v2/venues/explore?client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}".format(
        CLIENT_ID,
        CLIENT_SECRET,
        VERSION,
        lat,
        long,
        2000, 
        LIMIT)
    
    # Data recieved from FourSquare API.
    results = requests.get(url).json()["response"]['groups'][0]['items']
    
    # Add venues to list.
    for venue in results:
        venues.append((hood,
                       lat,
                       long,
                       venue['venue']['name'], 
            venue['venue']['location']['lat'], 
            venue['venue']['location']['lng'],  
            venue['venue']['categories'][0]['name']))

# %%
venuesDf = pd.DataFrame(venues)
venuesDf.columns = ["Neighborhood", "Latitude", "Longitude", "Venue Name", "Venue Latitude", "Venue Longitude", "Venue Category"]
venuesDf.head()
# Out:
#   Neighborhood   Latitude   Longitude                Venue Name  \
# 0      bel air  34.098883 -118.459881             Hotel Bel Air
# 1      bel air  34.098883 -118.459881    Getty Sculpture Garden
# 2      bel air  34.098883 -118.459881             Wolfgang Puck
# 3      bel air  34.098883 -118.459881  Oak Bar at Hotel Bel Air
# 4      bel air  34.098883 -118.459881             Bel Air Foods
#
#    Venue Latitude  Venue Longitude Venue Category
# 0       34.086611      -118.446362          Hotel
# 1       34.087560      -118.475748     Art Museum
# 2       34.086594      -118.446351     Restaurant
# 3       34.086209      -118.446144      Hotel Bar
# 4       34.116383      -118.464182  Grocery Store

# %% [markdown]
# # Cleaning the data

# %%
print("There are {} venue types in the datatype yet we only need one.".format(len(venuesDf["Venue Category"].unique())))
# Out:
# There are 463 venue types in the datatype yet we only need one.

# %%
# Only keep the venues that are hotels.
hotelDf = venuesDf[venuesDf["Venue Category"] == 'Hotel']

print("There are {} hotels in LA.".format(hotelDf.shape[0]))
hotelDf.head()
# Out:
# There are 240 hotels in LA.
#      Neighborhood   Latitude   Longitude            Venue Name  \
# 0         bel air  34.098883 -118.459881         Hotel Bel Air
# 47   hidden hills  34.164091 -118.657837     Hilton Garden Inn
# 380        malibu  34.035591 -118.689423      Malibu Beach Inn
# 390        malibu  34.035591 -118.689423            Malibu Inn
# 391        malibu  34.035591 -118.689423  The Surfrider Malibu
#
#      Venue Latitude  Venue Longitude Venue Category
# 0         34.086611      -118.446362          Hotel
# 47        34.151491      -118.648628          Hotel
# 380       34.038075      -118.674320          Hotel
# 390       34.037568      -118.677005          Hotel
# 391       34.037110      -118.677930          Hotel

# %%
# Create a datafreame with frequency of hotels with each neighborhood.
hotelFreqDf = hotelDf.groupby('Neighborhood').count()
hotelFreqDf.reset_index(inplace=True)

# Keep only the frequency and name.
hotelFreqDf = hotelFreqDf[["Neighborhood","Venue Category"]].astype(str)
hotelFreqDf.head()
# Out:
#    Neighborhood Venue Category
# 0  agoura hills              2
# 1       arcadia              6
# 2       artesia              1
# 3        avalon              9
# 4         azusa              1

# %% [markdown]
# # Segmenting each neighborhood to a cluster

# %%
# Creating the dataframe for building or k-means model.
kMeansDf = hotelFreqDf.merge(totalLaDf, on = "Neighborhood")

# Dropping un-necessary columns.
kMeansDf = kMeanDf[["Venue Category","Median-Income"]]
kMeansDf.columns = ["Num of Hotels","Median-Income"]

# Casting Num of Hotels column to float
kMeansDf["Num of Hotels"] = kMeansDf["Num of Hotels"].astype(float)

# Normalizing the data.
kMeansDf["Num of Hotels"] = kMeansDf["Num of Hotels"] / kMeansDf["Num of Hotels"].max()
kMeansDf["Median-Income"] = kMeansDf["Median-Income"] / kMeansDf["Median-Income"].max()

kMeansDf.head()
# Out:
#    Num of Hotels  Median-Income
# 0       0.222222       0.565592
# 1       0.666667       0.364570
# 2       0.111111       0.291135
# 3       1.000000       0.255845
# 4       0.111111       0.256322

# %%
k = 4

# Creating the k-means model.
kMeans = KMeans(n_clusters = k,random_state = 0).fit(kMeansDf)

kMeans.labels_[:10]
# Out:
# array([3, 2, 0, 2, 0, 0, 3, 0, 0, 0], dtype=int32)

# %%
# Adding the cluster label for each neighborhood on the dataframe.
hotelFreqDf["Cluster"] = kMeans.labels_

# Getting full dataset.
finalDf = hotelFreqDf.merge(totalLaDf.copy(),on = "Neighborhood")

# Re-naming columns.
finalDf.columns = ["Neighborhood","Hotel-Count","Cluster","Latitude","Longitude","Median-Income"]

# Setting columns to numeric values for analysis ease.
finalDf["Hotel-Count"] = finalDf["Hotel-Count"].astype(float)

finalDf.head()
# Out:
#    Neighborhood  Hotel-Count  Cluster   Latitude   Longitude  Median-Income
# 0  agoura hills          2.0        3  34.147910 -118.765704       117608.0
# 1       arcadia          6.0        2  -0.193964  -78.492941        75808.0
# 2       artesia          1.0        0  33.869020 -118.079620        60538.0
# 3        avalon          9.0        2  33.342210 -118.327261        53200.0
# 4         azusa          1.0        0  34.133875 -117.905605        53299.0

# %% [markdown]
# # Analyzing the data

# %%
# Cluster 0
finalDf[finalDf["Cluster"] == 0]
# Out:
#             Neighborhood  Hotel-Count  Cluster   Latitude   Longitude  \
# 2                artesia          1.0        0  33.869020 -118.079620
# 4                  azusa          1.0        0  34.133875 -117.905605
# 5           baldwin park          2.0        0  34.085474 -117.961176
# 7                   bell          1.0        0  33.974781 -118.186636
# 8           bell gardens          2.0        0  33.969456 -118.150395
# 9             bellflower          1.0        0  33.896347 -118.117083
# 10         beverly grove          2.0        0  34.076034 -118.369972
# 13               burbank          2.0        0  34.181648 -118.325855
# 15                carson          2.0        0  33.832204 -118.251755
# 16               carthay          2.0        0  34.061121 -118.367300
# 20            chatsworth          1.0        0  34.259571 -118.602325
# 22             claremont          1.0        0  34.096676 -117.719779
# 23              commerce          1.0        0  34.002581 -118.156586
# 24                covina          1.0        0  34.082150 -117.872124
# 25                cudahy          2.0        0  33.962058 -118.183539
# 26           culver city          1.0        0  34.021122 -118.396467
# 29           diamond bar          2.0        0  34.028623 -117.810337
# 31            eagle rock          1.0        0  34.136688 -118.207680
# 34        harbor gateway          2.0        0  33.854225 -118.299220
# 35       harvard heights          2.0        0  34.047111 -118.305483
# 36             hawthorne          2.0        0  33.918859 -118.348326
# 41       hollywood hills          1.0        0  34.131179 -118.335547
# 43              industry          1.0        0  34.019734 -117.958675
# 44             inglewood          2.0        0  33.956200 -118.353132
# 45             koreatown          1.0        0  34.058013 -118.300809
# 47             lancaster          1.0        0  34.698106 -118.136615
# 48             larchmont          1.0        0  34.079837 -118.317870
# 50                lennox          2.0        0  33.939138 -118.351670
# 51                lomita          1.0        0  33.803655 -118.319501
# 53             los feliz          1.0        0  34.107656 -118.287506
# 57               maywood          1.0        0  33.986681 -118.185349
# 58              monrovia          2.0        0  34.148350 -118.001452
# 61                 palms          1.0        0  34.024733 -118.411615
# 62              pasadena          1.0        0  34.147645 -118.144478
# 63           pico rivera          1.0        0  33.983069 -118.096735
# 69              rosemead          1.0        0  34.067617 -118.087976
# 70             san pedro          1.0        0  33.735852 -118.292293
# 72           signal hill          1.0        0  33.804826 -118.168259
# 74     south san gabriel          2.0        0  34.049728 -118.094229
# 75  south san jose hills          1.0        0  34.014821 -117.915700
# 78           toluca lake          1.0        0  34.152169 -118.357142
# 79              torrance          2.0        0  33.835849 -118.340629
# 80               valinda          1.0        0  34.038478 -117.933559
# 81                venice          2.0        0  33.995044 -118.466887
# 82        vermont square          1.0        0  34.001945 -118.300213
# 83           west covina          1.0        0  34.068621 -117.938953
# 86              westlake          1.0        0  34.062923 -118.272820
# 88              westmont          1.0        0  33.941403 -118.302296
# 90              whittier          1.0        0  33.970878 -118.030840
# 91        windsor square          1.0        0  34.068973 -118.319988
# 92              winnetka          2.0        0  34.197449 -118.571006
#
#     Median-Income
# 2         60538.0
# 4         53299.0
# 5         56585.0
# 7         40556.0
# 8         41532.0
# 9         53325.0
# 10        63039.0
# 13        64416.0
# 15        70645.0
# 16        71398.0
# 20        84456.0
# 22        89804.0
# 23        46245.0
# 24        66438.0
# 25        39048.0
# 26        70774.0
# 29        92414.0
# 31        67253.0
# 34        47849.0
# 35        31173.0
# 36        43602.0
# 41        69277.0
# 43        66616.0
# 44        46574.0
# 45        30558.0
# 47        56069.0
# 48        47780.0
# 50        37937.0
# 51        59059.0
# 53        50793.0
# 57        41203.0
# 58        61504.0
# 61        50684.0
# 62        62825.0
# 63        56683.0
# 69        49387.0
# 70        57508.0
# 72        66283.0
# 74        64827.0
# 75        65527.0
# 78        73111.0
# 79        76866.0
# 80        70037.0
# 81        67647.0
# 82        29904.0
# 83        71898.0
# 86        26757.0
# 88        31572.0
# 90        66891.0
# 91        61767.0
# 92        62535.0

# %%
# Cluster 1
finalDf[finalDf["Cluster"] == 1]
# Out:
#              Neighborhood  Hotel-Count  Cluster   Latitude   Longitude  \
# 12            beverlywood          5.0        1  34.045933 -118.394920
# 28  desert view highlands          4.0        1  34.589978 -118.153456
# 30               downtown          4.0        1  34.042849 -118.247673
# 33            harbor city          3.0        1  33.797282 -118.300472
# 37          hermosa beach          4.0        1  33.864280 -118.395910
# 42   hollywood hills west          5.0        1  34.110485 -118.373388
# 49               lawndale          3.0        1  33.888522 -118.353199
# 56         marina del rey          5.0        1  33.977685 -118.448648
# 59             montebello          4.0        1  24.048652 -104.608102
# 60               palmdale          3.0        1  34.579313 -118.117111
# 64         pico robertson          5.0        1  34.053269 -118.386983
# 67                 ramona          3.0        1  19.050121  -98.217769
# 68          redondo beach          4.0        1  33.845591 -118.388677
# 71           santa monica          4.0        1  34.025072 -118.496513
# 73         south pasadena          4.0        1  34.113306 -118.147829
# 85            westchester          3.0        1  33.954098 -118.400047
# 89               westwood          4.0        1  34.066895 -118.439945
#
#     Median-Income
# 12       105253.0
# 28        80867.0
# 30        15003.0
# 33        55454.0
# 37       109509.0
# 42       108199.0
# 49        53150.0
# 56        92763.0
# 59        52623.0
# 60        63317.0
# 64        63356.0
# 67        86325.0
# 68        92263.0
# 71        69013.0
# 73        76229.0
# 85        77473.0
# 89        68716.0

# %%
# Cluster 2
finalDf[finalDf["Cluster"] == 2]
# Out:
#        Neighborhood  Hotel-Count  Cluster   Latitude   Longitude  \
# 1           arcadia          6.0        2  -0.193964  -78.492941
# 3            avalon          9.0        2  33.342210 -118.327261
# 11    beverly hills          6.0        2  34.069650 -118.396306
# 17  catalina island          9.0        2 -14.060373  -75.740348
# 18     century city          6.0        2  34.057426 -118.414727
# 27         del aire          7.0        2  33.923274 -118.374702
# 32         glendale          6.0        2  -0.193964  -78.492941
# 39    highland park          6.0        2  -0.193964  -78.492941
# 40        hollywood          6.0        2  34.098003 -118.329523
# 52       long beach          6.0        2  33.769016 -118.191605
# 65       pico union          5.0        2  34.046567 -118.287894
# 77       sun valley          6.0        2  -0.193964  -78.492941
# 84   west hollywood          7.0        2  34.092301 -118.369289
#
#     Median-Income
# 1         75808.0
# 3         53200.0
# 11        96312.0
# 17        56295.0
# 18        95135.0
# 27        66442.0
# 32        57112.0
# 39        45478.0
# 40        33694.0
# 52        50985.0
# 65        26424.0
# 77        51290.0
# 84        52855.0

# %%
# Cluster 3
finalDf[finalDf["Cluster"] == 3]
# Out:
#         Neighborhood  Hotel-Count  Cluster   Latitude   Longitude  \
# 0       agoura hills          2.0        3  34.147910 -118.765704
# 6            bel air          1.0        3  34.098883 -118.459881
# 14         calabasas          1.0        3  34.144664 -118.644097
# 19          cerritos          1.0        3  33.864429 -118.053932
# 21     cheviot hills          3.0        3  34.040588 -118.409887
# 38      hidden hills          1.0        3  34.164091 -118.657837
# 46    ladera heights          1.0        3  33.994179 -118.375354
# 54            malibu          3.0        3  34.035591 -118.689423
# 55   manhattan beach          1.0        3  33.891599 -118.395124
# 66      porter ranch          1.0        3  34.281816 -118.561271
# 76   stevenson ranch          1.0        3  34.388178 -118.585396
# 87  westlake village          3.0        3  34.146023 -118.806179
#
#     Median-Income
# 0        117608.0
# 6        207938.0
# 14       126178.0
# 19        98212.0
# 21       111813.0
# 38       203199.0
# 46       117925.0
# 54       138215.0
# 55       136481.0
# 66       121428.0
# 76       122833.0
# 87       126550.0

# %% [markdown]
# # What can we see?

# %%
finalDf.groupby("Cluster").mean()[["Hotel-Count","Median-Income"]]
# Out:
#          Hotel-Count  Median-Income
# Cluster
# 0           1.352941   57538.588235
# 1           3.941176   74677.235294
# 2           6.538462   58540.769231
# 3           1.583333  135698.333333

# %% [markdown]
# ### After segmenting each neighborhood into one of four clusters, you could see a difference in each cluster.
#
# ### Cluster 0 offers no competition among other hotels but it's median-household income suggests that it's a middle class area which hints that it's not ideal for an upscale hotel to be opened.
#
# ### Cluster 1 and 2 are both occupied by other hotels which would cause un-wanted competition for one to open a hotel, that  making both of those clusters non-suitable areas for such a business to be launched.
#
# ### Cluster 3 neighborhoods are by far the idealest neighborhoods to open hotels. Their income index suggests that those areas are wealthy and are not contested by other hotels nearby.

# %% [markdown]
# # Visualizing the data

# %%
# Create map object.
clusteredMap = folium.Map([latitude,longitude], 
                  zoom_start = 11, tiles = "stamentoner")
colors = ["coral","yellow","red","lime"]

# Plot each neighborhood to map and color it according to cluster.
for nHood,lat,long,clus in zip(finalDf["Neighborhood"],finalDf["Latitude"],finalDf["Longitude"],finalDf["Cluster"]):
    folium.CircleMarker(
    [lat,long],
    radius = 15,
    color = colors[clus],
    popup = "{}, cluster {}".format(nHood,clus),
    fill = True,
    fill_color = colors[clus],
    fill_opacity = .5).add_to(clusteredMap)
clusteredMap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # Conclusions
# ### By looking at the map, you could see which neighborhoods are worthy to open a luxury hotel in. If I was to rate the cluster in order, I would choose, Cluster 3 > Cluster 1 > Cluster <0 < Cluster 2.

# %% [markdown]
# ##### I hope that you found this presentation to be insightful. For any feedback, contact imrond2@gmail.com.
